# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = 'streetbusy.jpg'
from PIL import Image
img = Image.open(filename);

#resize image
img = img.resize((224,224))
plt.imshow(img)

# %%
#Load deep learning model
mobile = tf.keras.applications.mobilenet.MobileNet()

# %%
# Creating a model
## Training a model
### Test model
## Predictions

# %%
mobile = tf.keras.applications.mobilenet_v2.MobileNetV2()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224.h5
# 14540800/14536120 [==============================] - 3s 0us/step

# %%
# Pre-processing of the image
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size = (224,224))

# %%
resized_img = image.img_to_array(img)
final_image = np.expand_dims(resized_img, axis=0)
final_image = tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions = mobile.predict(final_image)

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
results = imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n03417042', 'garbage_truck', 0.2974448), ('n04335435', 'streetcar', 0.1264326), ('n03032252', 'cinema', 0.088943124), ('n03599486', 'jinrikisha', 0.05965303), ('n02930766', 'cab', 0.053458706)]]

# %%
print(results)
# Out:
# [[('n04335435', 'streetcar', 0.42331085), ('n02930766', 'cab', 0.06442869), ('n04486054', 'triumphal_arch', 0.049730774), ('n03837869', 'obelisk', 0.021034122), ('n03763968', 'military_uniform', 0.016870327)]]
